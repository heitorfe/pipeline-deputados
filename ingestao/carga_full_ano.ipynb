# %%
import pandas as pd
import requests
import os
import time

# %%
url = 'https://dadosabertos.camara.leg.br/arquivos/{item}/csv/{item}-{year}.csv'


def download_item(year, item, overwrite_csv=False, overwrite_parquet=True):
    
    source_path = '../data/{item}/csv'
    sink_path = '../data/{item}/parquet'
    source_path_formatted = os.path.abspath(source_path.format(item=item))
    sink_path_formatted = os.path.abspath(sink_path.format(item=item))
    url_formatted = url.format(item=item, year=year)

    os.makedirs(source_path_formatted, exist_ok=True)
    os.makedirs(sink_path_formatted, exist_ok=True)
    print(f"Directories ensured: {source_path_formatted}, {sink_path_formatted}")

    file_path = os.path.join(source_path_formatted, f'{item}-{year}.csv')
    if (not os.path.exists(file_path)) or overwrite_csv:
        print(f'Downloading {item}-{year}.csv...')
        response = requests.get(url_formatted)
        if response.status_code == 200:
            with open(file_path, 'wb') as f:
                f.write(response.content)
            print(f'File saved to {file_path}')
        else:
            print(f'Failed to download file for year {year}: {response.status_code}')
            raise Exception(f'Error downloading file for year {year}: {response.status_code}')
    else:
        print(f'File for year {year} already exists.')

    # Convert to parquet and save to sink_path
    parquet_file_path = os.path.join(sink_path_formatted, f'{item}-{year}.parquet')
    if (not os.path.exists(parquet_file_path)) or overwrite_parquet:
        print(f'Converting {file_path} to Parquet format...')
        df = pd.read_csv(file_path, sep=";").drop_duplicates()
        df.columns = [col.replace('.', '_') for col in df.columns]
        df.to_parquet(parquet_file_path, index=False)
        print(f'File saved to {parquet_file_path}')
    else:
        print(f'Parquet file for year {year} already exists.')
        
items = [
    # 'proposicoes', 'proposicoesTemas', 'proposicoesAutores', 'eventos', 'eventosOrgaos', 
    #         'eventosPresencaDeputados', 'eventosRequerimentos', 'votacoes', 'votacoesVotos', 
            'votacoesOrientacoes',
            # 'votacoesObjetos', 'votacoesProposicoes', 'licitacoes',
            # 'licitacoesContratos', 'licitacoesItens', 'licitacoesPedidos', 'licitacoesPropostas'
            ]
items = ['votacoesOrientacoes']
for year in range(2025, 2000 , -1):
    for item in items:
        try:
            download_item(year, item, overwrite_csv=True, overwrite_parquet=True)
            time.sleep(1)  # Sleep to avoid overwhelming the server
        except Exception as e:
            continue
# Out:
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2025.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2025.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2025.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2025.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2024.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2024.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2024.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2024.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2023.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2023.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2023.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2023.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2022.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2022.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2022.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2022.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2021.csv...
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2020.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2020.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2020.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2020.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2019.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2019.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2019.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2019.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2018.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2018.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2018.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2018.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2017.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2017.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2017.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2017.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2016.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2016.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2016.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2016.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2015.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2015.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2015.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2015.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2014.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2014.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2014.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2014.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2013.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2013.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2013.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2013.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2012.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2012.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2012.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2012.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2011.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2011.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2011.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2011.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2010.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2010.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2010.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2010.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2009.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2009.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2009.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2009.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2008.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2008.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2008.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2008.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2007.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2007.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2007.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2007.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2006.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2006.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2006.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2006.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2005.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2005.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2005.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2005.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2004.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2004.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2004.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2004.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2003.csv...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2003.csv
# Converting d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv\votacoesOrientacoes-2003.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet\votacoesOrientacoes-2003.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2002.csv...
# Failed to download file for year 2002: 404
# Directories ensured: d:\projetos\pipeline-deputados\data\votacoesOrientacoes\csv, d:\projetos\pipeline-deputados\data\votacoesOrientacoes\parquet
# Downloading votacoesOrientacoes-2001.csv...
# Failed to download file for year 2001: 404
