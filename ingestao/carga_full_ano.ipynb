# %%
import pandas as pd
import requests
import os
import time

# %%
url = 'https://dadosabertos.camara.leg.br/arquivos/{item}/csv/{item}-{year}.csv'


def download_item(year, item, overwrite_csv=False, overwrite_parquet=True):
    
    source_path = '../data/{item}/csv'
    sink_path = '../data/{item}/parquet'
    source_path_formatted = os.path.abspath(source_path.format(item=item))
    sink_path_formatted = os.path.abspath(sink_path.format(item=item))
    url_formatted = url.format(item=item, year=year)

    os.makedirs(source_path_formatted, exist_ok=True)
    os.makedirs(sink_path_formatted, exist_ok=True)
    print(f"Directories ensured: {source_path_formatted}, {sink_path_formatted}")

    file_path = os.path.join(source_path_formatted, f'{item}-{year}.csv')
    if (not os.path.exists(file_path)) or overwrite_csv:
        print(f'Downloading {item}-{year}.csv...')
        response = requests.get(url_formatted)
        if response.status_code == 200:
            with open(file_path, 'wb') as f:
                f.write(response.content)
            print(f'File saved to {file_path}')
        else:
            print(f'Failed to download file for year {year}: {response.status_code}')
            raise Exception(f'Error downloading file for year {year}: {response.status_code}')
    else:
        print(f'File for year {year} already exists.')

    # Convert to parquet and save to sink_path
    parquet_file_path = os.path.join(sink_path_formatted, f'{item}-{year}.parquet')
    if (not os.path.exists(parquet_file_path)) or overwrite_parquet:
        print(f'Converting {file_path} to Parquet format...')
        df = pd.read_csv(file_path, sep=";").drop_duplicates()
        df.columns = [col.replace('.', '_') for col in df.columns]
        df.to_parquet(parquet_file_path, index=False)
        print(f'File saved to {parquet_file_path}')
    else:
        print(f'Parquet file for year {year} already exists.')
        
items = ['proposicoes', 'proposicoesTemas', 'proposicoesAutores', 'eventos', 'eventosOrgaos', 
            'eventosPresencaDeputados', 'eventosRequerimentos', 'votacoes', 'votacoesVotos', 
            'VotacoesOrientacoes', 'votacoesObjetos', 'votacoesProposicoes', 'licitacoes',
            'licitacoesContratos', 'licitacoesItens', 'licitacoesPedidos', 'licitacoesPropostas']
items = ['eventos']
for year in range(2025, 2000 , -1):
    for item in items:
        try:
            download_item(year, item, overwrite_csv=False, overwrite_parquet=True)
            time.sleep(1)  # Sleep to avoid overwhelming the server
        except Exception as e:
            continue
# Out:
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2025 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2025.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2025.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2024 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2024.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2024.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2023 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2023.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2023.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2022 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2022.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2022.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2021 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2021.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2021.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2020 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2020.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2020.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2019 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2019.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2019.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2018 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2018.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2018.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2017 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2017.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2017.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2016 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2016.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2016.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2015 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2015.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2015.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2014 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2014.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2014.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2013 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2013.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2013.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2012 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2012.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2012.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2011 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2011.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2011.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2010 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2010.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2010.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2009 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2009.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2009.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2008 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2008.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2008.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2007 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2007.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2007.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2006 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2006.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2006.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2005 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2005.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2005.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2004 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2004.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2004.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2003 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2003.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2003.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2002 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2002.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2002.parquet
# Directories ensured: d:\projetos\pipeline-deputados\data\eventos\csv, d:\projetos\pipeline-deputados\data\eventos\parquet
# File for year 2001 already exists.
# Converting d:\projetos\pipeline-deputados\data\eventos\csv\eventos-2001.csv to Parquet format...
# File saved to d:\projetos\pipeline-deputados\data\eventos\parquet\eventos-2001.parquet
